# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
from IPython.display import display
from tqdm import tqdm
from collections import Counter
import ast

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import seaborn as sb

from sklearn.feature_extraction.text import CountVectorizer
from textblob import TextBlob
import scipy.stats as stats

from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.manifold import TSNE

from bokeh.plotting import figure, output_file, show
from bokeh.models import Label
from bokeh.io import output_notebook
output_notebook()

from langdetect import detect

# %matplotlib inline
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Importing Data

# %%
r=pd.read_csv("C:\\Users\\sarka\\OneDrive\\Desktop\\Data\\Capetown\\Capetown.csv")
r1= pd.read_csv("C:\\Users\\sarka\\OneDrive\\Desktop\\Data\\bejing\\reviews.csv")
r2= pd.read_csv("C:\\Users\\sarka\\OneDrive\\Desktop\\Data\\Lisbon\\reviews.csv")
r3= pd.read_csv("C:\\Users\\sarka\\OneDrive\\Desktop\\Data\\Istanbul\\reviews.csv")
r4= pd.read_csv("C:\\Users\\sarka\\OneDrive\\Desktop\\Data\\London\\reviews.csv")
r5= pd.read_csv("C:\\Users\\sarka\\OneDrive\\Desktop\\Data\\NewYork\\reviews.csv")
r6= pd.read_csv("C:\\Users\\sarka\\OneDrive\\Desktop\\Data\\Paris\\reviews.csv")
r7= pd.read_csv("C:\\Users\\sarka\\OneDrive\\Desktop\\Data\\Rome\\reviews.csv")
r8= pd.read_csv("C:\\Users\\sarka\\OneDrive\\Desktop\\Data\\Sydney\\reviews.csv")
r9= pd.read_csv("C:\\Users\\sarka\\OneDrive\\Desktop\\Data\\Tokyo\\reviews.csv")
r10= pd.read_csv("C:\\Users\\sarka\\OneDrive\\Desktop\\Data\\Victoria\\reviews.csv")
r11= pd.read_csv("C:\\Users\\sarka\\OneDrive\\Desktop\\Data\\Rio de janerio\\reviews.csv")

# %%
l=pd.read_csv("C:\\Users\\sarka\\OneDrive\\Desktop\\Data\\Capetown\\listings.csv")
l1= pd.read_csv("C:\\Users\\sarka\\OneDrive\\Desktop\\Data\\bejing\\listings.csv")
l2= pd.read_csv("C:\\Users\\sarka\\OneDrive\\Desktop\\Data\\Lisbon\\listings.csv")
l3= pd.read_csv("C:\\Users\\sarka\\OneDrive\\Desktop\\Data\\Istanbul\\listings.csv")
l4= pd.read_csv("C:\\Users\\sarka\\OneDrive\\Desktop\\Data\\London\\listings.csv")
l5= pd.read_csv("C:\\Users\\sarka\\OneDrive\\Desktop\\Data\\NewYork\\listings.csv")
l6= pd.read_csv("C:\\Users\\sarka\\OneDrive\\Desktop\\Data\\Paris\\listings.csv")
l7= pd.read_csv("C:\\Users\\sarka\\OneDrive\\Desktop\\Data\\Rome\\listings.csv")
l8= pd.read_csv("C:\\Users\\sarka\\OneDrive\\Desktop\\Data\\Sydney\\listings.csv")
l9= pd.read_csv("C:\\Users\\sarka\\OneDrive\\Desktop\\Data\\Tokyo\\listings.csv")
l10= pd.read_csv("C:\\Users\\sarka\\OneDrive\\Desktop\\Data\\Victoria\\listings.csv")
l11= pd.read_csv("C:\\Users\\sarka\\OneDrive\\Desktop\\Data\\Rio de janerio\\listings.csv")
# Out:
# C:\Users\sarka\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (43,61,62) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\sarka\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (43,61,62,95) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\sarka\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (61,62) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\sarka\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (43,61,62,94) have mixed types.Specify dtype option on import or set low_memory=False.
# ...

# %% [markdown]
# ## Data Manipulation

# %%
r['Location']='CapeTown'
r1['Location']='Bejing'
r2['Location']='Lisbon'
r3['Location']='Istanbul'
r4['Location']='London'
r5['Location']='NewYork'
r6['Location']='Paris'
r7['Location']='Rome'
r8['Location']='Sydney'
r9['Location']='Tokyo'
r10['Location']='Victoria'
r11['Location']='RioDeJanerio'

# %%
l=l.rename(columns={'id':'listing_id'})
l1=l1.rename(columns={'id':'listing_id'})
l2=l2.rename(columns={'id':'listing_id'})
l3=l3.rename(columns={'id':'listing_id'})
l4=l4.rename(columns={'id':'listing_id'})
l5=l5.rename(columns={'id':'listing_id'})
l6=l6.rename(columns={'id':'listing_id'})
l7=l7.rename(columns={'id':'listing_id'})
l8=l8.rename(columns={'id':'listing_id'})
l9=l9.rename(columns={'id':'listing_id'})
l10=l10.rename(columns={'id':'listing_id'})
l11=l11.rename(columns={'id':'listing_id'})

# %%
l=l[['listing_id','host_id','host_is_superhost','host_identity_verified','room_type','city','review_scores_rating']]
l1=l1[['listing_id','host_id','host_is_superhost','host_identity_verified','room_type','city','review_scores_rating']]
l2=l2[['listing_id','host_id','host_is_superhost','host_identity_verified','room_type','city','review_scores_rating']]
l3=l3[['listing_id','host_id','host_is_superhost','host_identity_verified','room_type','city','review_scores_rating']]
l4=l4[['listing_id','host_id','host_is_superhost','host_identity_verified','room_type','city','review_scores_rating']]
l5=l5[['listing_id','host_id','host_is_superhost','host_identity_verified','room_type','city','review_scores_rating']]
l6=l6[['listing_id','host_id','host_is_superhost','host_identity_verified','room_type','city','review_scores_rating']]
l7=l7[['listing_id','host_id','host_is_superhost','host_identity_verified','room_type','city','review_scores_rating']]
l8=l8[['listing_id','host_id','host_is_superhost','host_identity_verified','room_type','city','review_scores_rating']]
l9=l9[['listing_id','host_id','host_is_superhost','host_identity_verified','room_type','city','review_scores_rating']]
l10=l10[['listing_id','host_id','host_is_superhost','host_identity_verified','room_type','city','review_scores_rating']]
l11=l11[['listing_id','host_id','host_is_superhost','host_identity_verified','room_type','city','review_scores_rating']]

# %%
d=pd.merge(l,r,on='listing_id')
d1=pd.merge(l1,r1,on='listing_id')
d2=pd.merge(l2,r2,on='listing_id')
d3=pd.merge(l3,r3,on='listing_id')
d4=pd.merge(l4,r4,on='listing_id')
d5=pd.merge(l5,r5,on='listing_id')
d6=pd.merge(l6,r6,on='listing_id')
d7=pd.merge(l7,r7,on='listing_id')
d8=pd.merge(l8,r8,on='listing_id')
d9=pd.merge(l9,r9,on='listing_id')
d10=pd.merge(l10,r10,on='listing_id')
d11=pd.merge(l11,r11,on='listing_id')

# %%
d=d.dropna()
d1=d1.dropna()
d2=d2.dropna()
d3=d3.dropna()
d4=d4.dropna()
d5=d5.dropna()
d6=d6.dropna()
d7=d7.dropna()
d8=d8.dropna()
d9=d9.dropna()
d10=d10.dropna()
d11=d11.dropna()

# %%
d=d.sample(n=5000)
d1=d1.sample(n=5000)
d2=d2.sample(n=5000)
d3=d3.sample(n=5000)
d4=d4.sample(n=5000)
d5=d5.sample(n=5000)
d6=d6.sample(n=5000)
d7=d7.sample(n=5000)
d8=d8.sample(n=5000)
d9=d9.sample(n=5000)
d10=d10.sample(n=5000)
d11=d11.sample(n=5000)

# %% [markdown]
# ## Data Preprocessing

# %%
def langr(df):
    for index, row in df['comments'].iteritems():
            try:
                lang = detect(row) #detecting each row
                df.loc[index, 'Languagereveiw'] = lang
            except:
                'skip'
    return(df)

# %%
k =[d,d1,d2,d3,d4,d5,d6,d7,d8,d9,d10]
for i in k:
    langr(i)

# %%
def isengli(df):
    langr(df)
    is_eng=(df['Languagereveiw']=='en')
    df=df[is_eng]
    print(df.shape)
    return(df)

# %%
k =[d,d1,d2,d3,d4,d5,d6,d7,d8,d9,d10]
for i in k:
    isengli(i)
# Out:
# (4530, 14)
# (523, 14)
# (3070, 14)
# (3642, 14)
# (4332, 14)
# (4410, 14)
# (3094, 14)
# (3365, 14)
# (4681, 14)
# (3147, 14)
# (4808, 14)

# %%
D=([d,d1,d2,d3,d4,d5,d6,d7,d8,d9,d10,d11])
df=pd.concat(D)
df
# Out:
#         listing_id    host_id host_is_superhost host_identity_verified  \
# 279356    25879821  116561036                 t                      f
# 230401    20633081  147490490                 t                      f
# 200414    17376850   13286229                 t                      f
# 257936    22364747  163542000                 f                      f
# 237132    21180170   23441517                 t                      t
# ...            ...        ...               ...                    ...
# 193816    13615100   64150350                 f                      t
# 215774    15134765   13825647                 f                      f
# 305106    30534238  229116116                 t                      f
# 242916    18159534     561376                 t                      t
# 188853    13216913   16634521                 f                      f
#
#               room_type            city  review_scores_rating         id  \
# ...

# %%
df.dropna()
# Out:
#         listing_id    host_id host_is_superhost host_identity_verified  \
# 279356    25879821  116561036                 t                      f
# 230401    20633081  147490490                 t                      f
# 200414    17376850   13286229                 t                      f
# 257936    22364747  163542000                 f                      f
# 237132    21180170   23441517                 t                      t
# ...            ...        ...               ...                    ...
# 74942     15463719   81909262                 f                      f
# 10973      1471669    7879272                 t                      f
# 114531    20995841   80582852                 t                      f
# 65458     13784036   77244494                 f                      t
# 125916    23772352  111030248                 f                      f
#
#               room_type                city  review_scores_rating         id  \
# ...

# %%
df['cities']=df['city'].apply(lambda x: " ".join(x.lower() for x in str(x).split()))
df['cities']=df['cities'].str.replace('roma','rome')
df['cities']=df['cities'].str.replace('bejing','beijing')
df['cities']=df['cities'].str.replace(r' ','')

# %%
ct=['capetown','london','beijing','lisbon','istanbul','paris','rome','newyork','tokyo', 'riodejaneiro','victoria','sydney','rio']

# %%
df['plc']=""

# %%
j=0
for i in df['cities']:
    if(i in ct):
        df['plc'].iloc[j]=df['Location'].iloc[j]
    else:
        df['plc'].iloc[j]="suburbs"
    if(i=="nan"):
        df['plc'].iloc[j]="NaN"
    j=j+1
df
# Out:
# C:\Users\sarka\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#         listing_id    host_id host_is_superhost host_identity_verified  \
# 279356    25879821  116561036                 t                      f
# 230401    20633081  147490490                 t                      f
# 200414    17376850   13286229                 t                      f
# 257936    22364747  163542000                 f                      f
# 237132    21180170   23441517                 t                      t
# ...            ...        ...               ...                    ...
# 193816    13615100   64150350                 f                      t
# ...

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Thematic Analysis

# %%
from nltk.corpus import wordnet
def get_wordnet_pos(pos_tag):
    if pos_tag.startswith('J'):
        return wordnet.ADJ
    elif pos_tag.startswith('V'):
        return wordnet.VERB
    elif pos_tag.startswith('N'):
        return wordnet.NOUN
    elif pos_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN
import string
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.tokenize import WhitespaceTokenizer
from nltk.stem import WordNetLemmatizer

# %%
s=['i', 'me', 'my', 'myself', 'the','we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'further', 'then', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'only', 'own', 'same', 'so', 'than', 'too', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'couldn', "couldn't", 'didn', 'haven', 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
print(s)

# %%
import re
from nltk.corpus import stopwords
stop = stopwords.words('english')

# %%
def clean_text(text):
    # lower text
    text = text.lower()
    # tokenize text and remove puncutation
    text = [word.strip(string.punctuation) for word in text.split(" ")]
    # remove words that contain numbers
    text = [word for word in text if not any(c.isdigit() for c in word)]
    # remove stop words
    text = [x for x in text if x not in s]
    # remove empty tokens
    text = [t for t in text if len(t) > 0]
    # pos tag text
    pos_tags = pos_tag(text)
    # lemmatize text
    text = [WordNetLemmatizer().lemmatize(t[0], get_wordnet_pos(t[1])) for t in pos_tags]
    # remove words with only one letter
    text = [t for t in text if len(t) > 2]
    # join all
    text = " ".join(text)
    return(text)

# %%
df["review_clean"] = df["comments"].apply(lambda x: clean_text(x))

# %%
import spacy
nlp = spacy.load('en_core_web_lg', parse=True, tag=True, entity=True)

# %%
df['noun']=""
df['verb']=""
for x in (range(len(df['review_clean']))):
    lines = str(df['review_clean'].iloc[x])
    doc =nlp(lines)
    str1=" "
    str2=" "
    for token in doc:
        if token.pos_ is 'NOUN':
            str1=str1+ " "+token.text
            df['noun'].iloc[x]=str1
        if token.pos_ is 'VERB':
            str2= str2 + " " +token.text
            df['verb'].iloc[x]=str2
df
# Out:
# C:\Users\sarka\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#         listing_id    host_id host_is_superhost host_identity_verified  \
# 279356    25879821  116561036                 t                      f
# 230401    20633081  147490490                 t                      f
# 200414    17376850   13286229                 t                      f
# 257936    22364747  163542000                 f                      f
# 237132    21180170   23441517                 t                      t
# ...            ...        ...               ...                    ...
# 193816    13615100   64150350                 f                      t
# ...

# %%
def get_top_n_words(n_top_words, count_vectorizer, text_data):
    '''
    returns a tuple of the top n words in a sample and their 
    accompanying counts, given a CountVectorizer object and text sample
    '''
    vectorized_headlines = count_vectorizer.fit_transform(text_data.values)
    vectorized_total = np.sum(vectorized_headlines, axis=0)
    word_indices = np.flip(np.argsort(vectorized_total)[0,:], 1)
    word_values = np.flip(np.sort(vectorized_total)[0,:],1)
    
    word_vectors = np.zeros((n_top_words, vectorized_headlines.shape[1]))
    for i in range(n_top_words):
        word_vectors[i,word_indices[0,i]] =1

    words = [word[0].encode('ascii').decode('utf-8') for 
             word in count_vectorizer.inverse_transform(word_vectors)]

    return (words, word_values[0,:n_top_words].tolist()[0])

# %%
count_vectorizer = CountVectorizer(stop_words='english')
words, word_values = get_top_n_words(n_top_words=50,
                                     count_vectorizer=count_vectorizer, 
                                     text_data=df['noun'])

fig, ax = plt.subplots(figsize=(16,8))
ax.bar(range(len(words)), word_values);
ax.set_xticks(range(len(words)));
ax.set_xticklabels(words, rotation='vertical');
ax.set_title('Top non in Airbnb review (excluding stop words)');
ax.set_xlabel('Word');
ax.set_ylabel('Number of occurences');
plt.show()

# %%
count_vectorizer = CountVectorizer(stop_words='english')
words, word_values = get_top_n_words(n_top_words=50,
                                     count_vectorizer=count_vectorizer, 
                                     text_data=df['verb'])

fig, ax = plt.subplots(figsize=(16,8))
ax.bar(range(len(words)), word_values);
ax.set_xticks(range(len(words)));
ax.set_xticklabels(words, rotation='vertical');
ax.set_title('Top non in Airbnb review (excluding stop words)');
ax.set_xlabel('Word');
ax.set_ylabel('Number of occurences');
plt.show()

# %% [markdown]
# ## Content Analysis

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from tqdm import tqdm
nlp = spacy.load('en_core_web_sm', parse=True, tag=True, entity=True)
ner = spacy.load("en_core_web_sm")

# %%
verb=[*]

# %%
print(z)

# %%
df['Asp']=""

# %%
df['review_clean'].iloc[5]

# %%
df['Asp']=""

# %%
txt = df['review_clean'].iloc[9]
doc = nlp(txt)
spacy.displacy.render(doc,style='dep',jupyter=True)

# %%
topics=["location","person", "host", "apartment",'service','hostess'
        "communication", "room", 'area', 'restaurant', 'stay', 'space', 'station',
        'home', 'people', 'night', 'bed', 'day', 'city', 'kitchen', 'family',
        'bathroom', 'house', 'view', 'shop', 'street', 'amenities', 'value','place',
        'access', 'places', 'questions', 'neighborhood','beach','electricity','breakfast','wifi','hospitality']

# %%
m=0
df['word']=""
for h in df['review_clean']:
    doc=nlp(h)
    x=[]
    l=(len(doc))
    i=0
    z=[]
    for token in doc:
        k=token.text
        str1=""
        str2=""
        str3=""
        str4=""
        str7=""
        y=[]
        if(i<=l):
            if k in topics:
                for j in token.lefts:
                    if k not in x :
                        if j.dep_ is 'amod' and j.pos_ is 'ADJ':
                            str1 = j.text+' '+token.text
                            n=str1
                            for r in j.lefts:
                                if r.dep_ is 'advmod':
                                    str2 = r.text+' '+j.text+' '+token.text
                                    n=str2
                                if r.dep_ is 'neg':
                                    str7 = r.text+' '+j.text+' '+token.text
                                    n=str7
                            x.append(token.text)
                            z.append(n)
                    if k not in x:
                        if j.dep_ is 'neg' and j.pos_ is 'ADJ':
                            str3=(j.text+' '+token.text)
                            n=str3
                            x.append(token.text)
                            z.append(n)
                for j in token.rights:
                    if k not in x :
                        if j.dep_ is 'amod' and j.pos_ is 'ADJ':
                            str1 = j.text+' '+token.text
                            n=str1
                            for r in j.lefts:
                                if r.dep_ is 'advmod':
                                    str2 = r.text+' '+j.text+' '+token.text
                                    n=str2
                            x.append(token.text)
                            z.append(n)
                    if k not in x:
                        if j.dep_ is 'neg' and j.pos_ is 'ADJ':
                            str3=(j.text+' '+token.text)
                            x.append(token.text)
                            z.append(n)
                if(k not in x):
                    if(i<l-1):
                        r=doc[i+1]
                        if r.dep_ is 'amod' or r.pos_ is 'ADJ':
                            str6= r.text+ " "+ token.text
                            n=str6
                            x.append(token.text)
                            z.append(n)
                    elif r.dep_ is 'compound'and r.text in verb:
                        str11= r.text+ " "+token.text
                        n=str11
                        x.append(token.text)
                        z.append(n)
                if(k not in x):
                    if(i<l-2):
                        r=doc[i+2]
                        if r.dep_ is 'amod' or r.pos_ is 'ADJ':
                            str8= r.text+ " "+ token.text
                            n=str8
                            x.append(token.text)
                            z.append(n)
                if (k not in x):
                    if(i>0):
                        r=doc[i-1]
                        if r.dep_ is 'amod' or r.pos_ is 'ADJ':
                            str5= r.text+ " "+ token.text
                            n=str5
                            x.append(token.text)
                            z.append(n)
                    elif r.dep_ is 'compound'and r.text in verb:
                        str11= r.text+ " "+token.text
                        n=str11
                        x.append(token.text)
                        z.append(n,"e")
                df['Asp'].iloc[m]=z
                df['word'].iloc[m]=x
            i=i+1
    m=m+1
# Out:
# C:\Users\sarka\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df[['review_clean','Asp']].head()

# %%
sim=[]
for i in cate:
    token=nlp(i)
    for i in topics:
        doc=nlp(i)
        k=(token.text, doc.text,token.similarity(doc))
        sim.append(k)

# %%
s=pd.DataFrame(sim)
s

# %%
#host
a=['person', 'host', 'people','family','questions','hostess']
#neighborhood
b=c=['area','restaurant','station','places','night','view','day','city','shop','street','neighborhood','location','beach']
#service
c=['service','communication','value','stay','wifi','electricity','hospitality','amenities','access','breakfast']
#place
d=['apartment','room','kitchen','bathroom','house','space','home','bed','view','place']

# %%
my_df = pd.DataFrame(columns =['row_index','location','aspect_adj_string','pos_score','neg_score','compound_score','neutral_score'])
global_sentiment = {}
k=0
d=len(df)
for aspect_adj_tuple in df.Asp.iteritems():
    row_sentiment = {}
    for text in aspect_adj_tuple[1]:
        sentiment_array = []
        polarity = analyser.polarity_scores(text)
        my_df = my_df.append({'row_index':aspect_adj_tuple[0],'location':df['Location'].iloc[k],'Listing':df['listing_id'].iloc[k], 'aspect_adj_string':text,'pos_score':polarity['pos'],'neg_score':polarity['neg'],'compound_score':polarity['compound'],'neutral_score':polarity['neu']},ignore_index=True)
    if(k<=d):
        k=k+1

# %%
#host
a=['person', 'host', 'people','family','questions','hostess']
#neighborhood
b=['area','restaurant','station','places','night','view','day','city','shop','street','neighborhood','location','beach']
#service
c=['service','communication','value','stay','wifi','electricity','hospitality','amenities','access','breakfast']
#place
j=['apartment','room','kitchen','bathroom','house','space','home','bed','view','place']

# %%
my_df['category']=""
my_df['aspects']=""
n=0
for i in my_df['aspect_adj_string']:
    doc=nlp(i)
    for token in doc:
        if(token.text in a):
            my_df['category'].iloc[n]="host"
            my_df['aspects'].iloc[n]=token.text
        if(token.text in b):
            my_df['category'].iloc[n]="neighborhood"
            my_df['aspects'].iloc[n]=token.text
        if(token.text in c):
            my_df['category'].iloc[n]="service"
            my_df['aspects'].iloc[n]=token.text
        if(token.text in j):
            my_df['category'].iloc[n]="feature of the apartment"
            my_df['aspects'].iloc[n]=token.text
    n=n+1

# %%
my_df=my_df[((my_df['compound_score']>0.1) | (my_df['compound_score']< -0.1))]

# %%
my_df['sent']=""
k=0
for i in my_df['compound_score']:
    if(i<0):
        my_df['sent'].iloc[k]="neg"
    else:
        my_df['sent'].iloc[k]="pos"
    k=k+1

# %%
my_df
# Out:
#        row_index      location   aspect_adj_string  pos_score  neg_score  \
# 0         279356      CapeTown         great place      0.804        0.0
# 1         279356      CapeTown          great host      0.804        0.0
# 2         279356      CapeTown   comfortable house      0.767        0.0
# 3         279356      CapeTown          great stay      0.804        0.0
# 4         230401      CapeTown     excellent space      0.787        0.0
# ...          ...           ...                 ...        ...        ...
# 102091     78411  RioDeJanerio        amazing view      0.792        0.0
# 102092     78411  RioDeJanerio      great location      0.804        0.0
# 102095    100432  RioDeJanerio  clean neighborhood      0.730        0.0
# 102096    100432  RioDeJanerio    great restaurant      0.804        0.0
# 102099    145607  RioDeJanerio      wonderful host      0.787        0.0
#
#         compound_score  neutral_score     Listing                  category  \
# ...

# %%
R=pd.get_dummies(my_df,columns=['sent'])
R
# Out:
#        row_index      location   aspect_adj_string  pos_score  neg_score  \
# 0         279356      CapeTown         great place      0.804        0.0
# 1         279356      CapeTown          great host      0.804        0.0
# 2         279356      CapeTown   comfortable house      0.767        0.0
# 3         279356      CapeTown          great stay      0.804        0.0
# 4         230401      CapeTown     excellent space      0.787        0.0
# ...          ...           ...                 ...        ...        ...
# 102091     78411  RioDeJanerio        amazing view      0.792        0.0
# 102092     78411  RioDeJanerio      great location      0.804        0.0
# 102095    100432  RioDeJanerio  clean neighborhood      0.730        0.0
# 102096    100432  RioDeJanerio    great restaurant      0.804        0.0
# 102099    145607  RioDeJanerio      wonderful host      0.787        0.0
#
#         compound_score  neutral_score     Listing                  category  \
# ...

# %%
K2=R.groupby(['location','category']).sum().reset_index()
K2
# Out:
#         location                  category  pos_score  neg_score  \
# 0         Bejing  feature of the apartment    207.933      5.267
# 1         Bejing                      host    105.204      1.104
# 2         Bejing              neighborhood    122.309      3.573
# 3         Bejing                   service     91.953      0.000
# 4       CapeTown  feature of the apartment   2555.487     15.462
# 5       CapeTown                      host    885.799      6.804
# 6       CapeTown              neighborhood   1291.468     12.503
# 7       CapeTown                   service    915.401      8.112
# 8       Istanbul  feature of the apartment   1798.261     26.219
# 9       Istanbul                      host    814.706      4.772
# 10      Istanbul              neighborhood   1291.936     24.415
# 11      Istanbul                   service    656.473     14.693
# 12        Lisbon  feature of the apartment   1730.189     16.438
# ...

# %%
K4=pd.DataFrame(R.groupby(['location'])['Listing'].nunique())
K4
# Out:
#               Listing
# location
# Bejing            317
# CapeTown         2711
# Istanbul         1875
# Lisbon           2139
# London           2892
# NewYork          3055
# Paris            2225
# RioDeJanerio      878
# Rome             2424
# Sydney           2878
# Tokyo            1883
# Victoria         1524

# %%
final= pd.merge(K2,K4, on='location')
final
# Out:
#         location                  category  pos_score  neg_score  \
# 0         Bejing  feature of the apartment    207.933      5.267
# 1         Bejing                      host    105.204      1.104
# 2         Bejing              neighborhood    122.309      3.573
# 3         Bejing                   service     91.953      0.000
# 4       CapeTown  feature of the apartment   2555.487     15.462
# 5       CapeTown                      host    885.799      6.804
# 6       CapeTown              neighborhood   1291.468     12.503
# 7       CapeTown                   service    915.401      8.112
# 8       Istanbul  feature of the apartment   1798.261     26.219
# 9       Istanbul                      host    814.706      4.772
# 10      Istanbul              neighborhood   1291.936     24.415
# 11      Istanbul                   service    656.473     14.693
# 12        Lisbon  feature of the apartment   1730.189     16.438
# ...

# %%
final[['pos_score','neg_score','compound_score','neutral_score','sent_neg','sent_pos']] = final[['pos_score','neg_score','compound_score','neutral_score','sent_neg','sent_pos']].div(final.Listing_y, axis=0)

# %%
final
# Out:
#         location                  category  pos_score  neg_score  \
# 0         Bejing  feature of the apartment   0.655940   0.016615
# 1         Bejing                      host   0.331874   0.003483
# 2         Bejing              neighborhood   0.385833   0.011271
# 3         Bejing                   service   0.290073   0.000000
# 4       CapeTown  feature of the apartment   0.942636   0.005703
# 5       CapeTown                      host   0.326743   0.002510
# 6       CapeTown              neighborhood   0.476381   0.004612
# 7       CapeTown                   service   0.337662   0.002992
# 8       Istanbul  feature of the apartment   0.959073   0.013983
# 9       Istanbul                      host   0.434510   0.002545
# 10      Istanbul              neighborhood   0.689033   0.013021
# 11      Istanbul                   service   0.350119   0.007836
# 12        Lisbon  feature of the apartment   0.808878   0.007685
# ...

# %%
final[['pos_score','neg_score','compound_score','neutral_score','category_feature of the apartment','category_host','category_neighborhood','category_service']] = final[['pos_score','neg_score','compound_score','neutral_score','category_feature of the apartment','category_host','category_neighborhood','category_service']].div(final.Listing_y, axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-80-47866bdbdb75> in <module>
# ----> 1 final[['pos_score','neg_score','compound_score','neutral_score','category_feature of the apartment','category_host','category_neighborhood','category_service']] = final[['pos_score','neg_score','compound_score','neutral_score','category_feature of the apartment','category_host','category_neighborhood','category_service']].div(final.Listing_y, axis=0)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ...

# %%
final
# Out:
#         location                  category  pos_score  neg_score  \
# 0         Bejing  feature of the apartment   0.655940   0.016615
# 1         Bejing                      host   0.331874   0.003483
# 2         Bejing              neighborhood   0.385833   0.011271
# 3         Bejing                   service   0.290073   0.000000
# 4       CapeTown  feature of the apartment   0.942636   0.005703
# 5       CapeTown                      host   0.326743   0.002510
# 6       CapeTown              neighborhood   0.476381   0.004612
# 7       CapeTown                   service   0.337662   0.002992
# 8       Istanbul  feature of the apartment   0.959073   0.013983
# 9       Istanbul                      host   0.434510   0.002545
# 10      Istanbul              neighborhood   0.689033   0.013021
# 11      Istanbul                   service   0.350119   0.007836
# 12        Lisbon  feature of the apartment   0.808878   0.007685
# ...

# %%
final['sumn']=final['category_feature of the apartment'] + final['category_host']+ final['category_neighborhood']+ final['category_service']

# %%
final[['category_feature of the apartment','category_host','category_neighborhood','category_service']] = final[['category_feature of the apartment','category_host','category_neighborhood','category_service']].div(final.sumn, axis=0)

# %%
final
# Out:
#         location  pos_score  neg_score  compound_score  neutral_score  \
# 0         Bejing   0.005248   0.000099        0.003502       0.001748
# 1       CapeTown   0.000769   0.000006        0.000544       0.000234
# 2       Istanbul   0.001297   0.000020        0.000887       0.000429
# 3         Lisbon   0.000873   0.000015        0.000605       0.000282
# 4         London   0.000606   0.000007        0.000416       0.000197
# 5        NewYork   0.000582   0.000009        0.000401       0.000187
# 6          Paris   0.000778   0.000011        0.000536       0.000252
# 7   RioDeJanerio   0.002286   0.000038        0.001581       0.000726
# 8           Rome   0.000759   0.000010        0.000525       0.000243
# 9         Sydney   0.000685   0.000007        0.000481       0.000210
# 10         Tokyo   0.000961   0.000017        0.000649       0.000323
# 11      Victoria   0.002345   0.000018        0.001651       0.000718
#
# ...

# %%
dd=final[['location','category_feature of the apartment','category_host','category_neighborhood','category_service']]
dd
# Out:
#         location  category_feature of the apartment  category_host  \
# 0         Bejing                           0.399719       0.199158
# 1       CapeTown                           0.454202       0.158910
# 2       Istanbul                           0.396807       0.179182
# 3         Lisbon                           0.431483       0.145635
# 4         London                           0.417393       0.179241
# 5        NewYork                           0.442363       0.163476
# 6          Paris                           0.418754       0.131819
# 7   RioDeJanerio                           0.397703       0.162059
# 8           Rome                           0.404137       0.155903
# 9         Sydney                           0.432052       0.150489
# 10         Tokyo                           0.425352       0.143012
# 11      Victoria                           0.459958       0.147449
#
#     category_neighborhood  category_service
# 0                0.235624          0.165498
# ...

# %%
l=dd.rename(columns={'category_feature of the apartment':'property', 'category_host':'host' ,'category_neighborhood':'neighborhood','category_service':'service'})
l
# Out:
#         location  property      host  neighborhood   service
# 0         Bejing  0.399719  0.199158      0.235624  0.165498
# 1       CapeTown  0.454202  0.158910      0.229866  0.157021
# 2       Istanbul  0.396807  0.179182      0.283760  0.140251
# 3         Lisbon  0.431483  0.145635      0.299682  0.123201
# 4         London  0.417393  0.179241      0.248191  0.155175
# 5        NewYork  0.442363  0.163476      0.255750  0.138411
# 6          Paris  0.418754  0.131819      0.331974  0.117453
# 7   RioDeJanerio  0.397703  0.162059      0.314760  0.125479
# 8           Rome  0.404137  0.155903      0.311806  0.128153
# 9         Sydney  0.432052  0.150489      0.274869  0.142589
# 10         Tokyo  0.425352  0.143012      0.281257  0.150379
# 11      Victoria  0.459958  0.147449      0.240252  0.152341

# %%
dd1=pd.melt(l,id_vars=['location'])
dd1
# Out:
#         location      variable     value
# 0         Bejing      property  0.399719
# 1       CapeTown      property  0.454202
# 2       Istanbul      property  0.396807
# 3         Lisbon      property  0.431483
# 4         London      property  0.417393
# 5        NewYork      property  0.442363
# 6          Paris      property  0.418754
# 7   RioDeJanerio      property  0.397703
# 8           Rome      property  0.404137
# 9         Sydney      property  0.432052
# 10         Tokyo      property  0.425352
# 11      Victoria      property  0.459958
# 12        Bejing          host  0.199158
# 13      CapeTown          host  0.158910
# 14      Istanbul          host  0.179182
# 15        Lisbon          host  0.145635
# 16        London          host  0.179241
# 17       NewYork          host  0.163476
# 18         Paris          host  0.131819
# 19  RioDeJanerio          host  0.162059
# 20          Rome          host  0.155903
# 21        Sydney          host  0.150489
# ...

# %%
dd1.to_csv('aa1.csv')

# %%
K=pd.DataFrame(my_df.groupby(['location'])['Listing'].nunique())
K=K.rename(columns={'Listing':'Total'})
K

# %%
K4=my_df.groupby(['location','Listing','category']).sum().reset_index()
K4

# %%
K1

# %%
final= pd.merge(K1,K ,on='location', right_index=True, how='outer')

final

# %%
K1=pd.DataFrame(my_df.groupby(['location','category'])['Listing'].nunique())
K1

# %%
import spacy

nlp = spacy.load("en_core_web_md")  # make sure to use larger model!
tokens = nlp(str(topics))

for token1 in tokens:
    for token2 in tokens:
        print(token1.text, token2.text, token1.similarity(token2))

# %%
np.random.seed(1234)
boxplot = df.boxplot(column=['review_scores_rating'])

# %%
import math
pos = []
c=0
for i in range(len(df)):
    if not math.isnan(df['review_scores_rating'].iloc[i]):
        if int(df['review_scores_rating'].iloc[i])>60:
            pos.append('1')
        else:
            pos.append('0')
            c=c+1
    else:
        pos.append('0')
df['Positive Review'] = pos
print(c)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# %%
import operator
sentiment = []
for i in range(len(df)):
    score_dict={'pos':0,'neg':0,'neu':0}
    l=len(df['Asp'].iloc[i])
    if l!=0: 
        for aspects in df['Asp'].iloc[i]:
            sent = analyser.polarity_scores(aspects)
            score_dict['neg'] += sent['neg']
            score_dict['pos'] += sent['pos']
            #score_dict['neu'] += sent['neu']
        score= score_dict['pos']-score_dict['neg']
        sentiment.append(max(score_dict.items(), key=operator.itemgetter(1))[0])
    else:
        sentiment.append('NaN')
df['sentiment'] = sentiment

# %%
int_sent = []
for sent in df['sentiment']:
    if sent is 'NaN':
        int_sent.append('NaN')
    elif sent is 'pos':
        int_sent.append('1')
    else:
        int_sent.append('0')
df['int_sent'] = int_sent

# %%
d = {'sent':df['Positive Review'],'sent_pred':df['int_sent']}
metric_df = pd.DataFrame(data=d)
metric_df = metric_df[metric_df.sent_pred != 'NaN']
metric_df.head()

# %%
from sklearn.metrics import accuracy_score,auc,f1_score,recall_score,precision_score
print('accuracy')
print(accuracy_score(metric_df.sent, metric_df.sent_pred))
print('f1 score')
print(f1_score(metric_df.sent, metric_df.sent_pred,pos_label='1'))
print('recall')
print(recall_score(metric_df.sent, metric_df.sent_pred,pos_label='1'))
print('precision')
print(precision_score(metric_df.sent, metric_df.sent_pred,pos_label='1'))

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()
my_df = pd.DataFrame(columns =['row_index','location','host','verified_host','area','room_type','superhost','aspect_adj_string','pos_score','neg_score','compound_score','neutral_score'])
global_sentiment = {}
k=0
d=len(df)
for aspect_adj_tuple in df.Asp.iteritems():
    row_sentiment = {}
    for text in aspect_adj_tuple[1]:
        sentiment_array = []
        polarity = analyser.polarity_scores(text)
        my_df = my_df.append({'row_index':aspect_adj_tuple[0],'location':df['Location'].iloc[k],'listing':df['listing_id'].iloc[k],'verified_host':df['host_identity_verified'].iloc[k], 'area':df['plc'].iloc[k], 'room_type':df['room_type'].iloc[k], 'superhost':df['host_is_superhost'].iloc[k] ,'aspect_adj_string':text,'pos_score':polarity['pos'],'neg_score':polarity['neg'],'compound_score':polarity['compound'],'neutral_score':polarity['neu']},ignore_index=True)
    if(k<=d):
        k=k+1

# %%
a=['communication','person', 'host', 'people','family','questions','access','value','stay']
b=[ 'apartment','room','kitchen','bathroom','house','space','home','amenities','bed','breakfast','space','view','place']

# %%
my_df['category']=""
my_df['aspects']=""

# %%
n=0
for i in my_df['aspect_adj_string']:
    doc=nlp(i)
    for token in doc:
        if(token.text in a):
            my_df['category'].iloc[n]="Interaction with the host"
            my_df['aspects'].iloc[n]=token.text
        if(token.text in b):
            my_df['category'].iloc[n]="features of place"
            my_df['aspects'].iloc[n]=token.text
        if(token.text in c):
            my_df['category'].iloc[n]="neighbourhood"
            my_df['aspects'].iloc[n]=token.text
    n=n+1

# %%
my_df

# %%
c=pd.read_excel("C:\\Users\\sarka\\OneDrive\\Desktop\\Data\\Hofseted.xlsx")
c.head()

# %%
c=c.rename(columns={'City':'location'})
c

# %%
final=pd.merge(c,my_df,on='location')

# %%
final

# %%
k=final.sample(n=10)
k

# %%
final['score']=""
j=0
for i in range(len(final)):
    j=(final['pos_score'].iloc[i])-(final['neg_score'].iloc[i])
    final['score'].iloc[i]=j

# %%
final

# %%
final = final[final.score != 0]
final

# %%
np.sum((final['neg_score'] > 0).values.ravel())

# %%
f=final[['location','Power Distance','Individualism','Masculinity','category','score','aspects']]
f.head()

# %%
r=f[f['score']!=0]
r
for i in range(len(r)):
    r['score'].iloc[i]=(r['score'].iloc[i])*100

# %%
r['score']=r['score'].astype(int)
r

# %%
J=r.groupby(['location','Power Distance','Individualism','Masculinity','superhost','verified_host']).mean().reset_index()

# %%
J=final.groupby(['location','host']).mean().reset_index()

# %%
J

# %%
matrix=pd.merge(j,J,on='location')
matrix

# %%
#R4 = r.groupby(['Power Distance','Individualism','Masculinity','category','room_type','superhost','verified_host'], as_index=False)['score'].mean()

# %%
for i in range(len(J)):
    J['superhost'].iloc[i]=int(J['superhost'].iloc[i]=='t')
    J['verified_host'].iloc[i]=int(J['verified_host'].iloc[i]=='t')

# %% [raw]
# k['score'].agg(lambda x: sum(x < 0)).sum()

# %% [markdown]
# r1=r.groupby(by=['superhost']).mean()
# r1

# %%
R=pd.get_dummies(J,columns=['room_type','category'])
R

# %%
z=pd.DataFrame(R)
corrMatrix = z.corr()
print(corrMatrix)

# %%
f, ax = plt.subplots(figsize=(20, 15))

heatmap = sns.heatmap(corrMatrix,
                      square = True,
                      linewidths = .5,
                      cmap = 'coolwarm',
                      cbar_kws = {'shrink': .4,
                                'ticks' : [-1, -.5, 0, 0.5, 1]},
                      vmin = -1,
                      vmax = 1,
                      annot = True,
                      annot_kws = {"size": 0})

#add the column names as labels
ax.set_yticklabels(corrMatrix.columns, rotation = 0)
ax.set_xticklabels(corrMatrix.columns)

sns.set_style({'xtick.bottom': True}, {'ytick.left': True})

# %%
print(R.columns)

# %%
X_final=j[[ 'Individualism', 'Masculinity', 'Power Distance']]

# %%
Y_final=j[['score']].copy()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X_final,Y_final,test_size=0.40,random_state =5)

# %%
n_scaler=MinMaxScaler()
X_train=n_scaler.fit_transform(X_train.astype(np.float))
X_test=n_scaler.transform(X_test.astype(np.float))

# %%
forest= RandomForestRegressor(n_estimators=5,criterion='mse',random_state=1,n_jobs=1)

# %%
forest.fit(X_train,Y_train.values.ravel())

# %%
y_train_pred=forest.predict(X_train)
y_test_pred=forest.predict(X_test)

# %%
forest.score(X_train,Y_train)

# %%
forest.score(X_test,Y_test)
